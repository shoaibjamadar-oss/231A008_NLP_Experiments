# %% [markdown]
# <a href="https://colab.research.google.com/github/shoaibjamadar-oss/231A008_NLP_Experiments/blob/main/NLP_EXP_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Name: Shoaib Jamadar","UIN :231A008")
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
from nltk.chunk import RegexpParser
# Out:
# Name: Shoaib Jamadar UIN :231A008

# %%
print("Name: Shoaib Jamadar","UIN :231A008")
sentence ="Barack Obama was the 44th President of the United States. He is married to Michelle Obama."
sentence1 ="I Saw ,I came, I conqured"
# Out:
# Name: Shoaib Jamadar UIN :231A008

# %%
print("Name: Shoaib Jamadar","UIN :231A008")
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
tokens = word_tokenize(sentence1)
tokens = word_tokenize(sentence)
tagged = pos_tag(tokens)
tagged
# Out:
# Name: Shoaib Jamadar UIN :231A008
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [('I', 'PRP'),
#  ('am', 'VBP'),
#  ('not', 'RB'),
#  ('afraid', 'JJ'),
#  ('of', 'IN'),
#  ('an', 'DT'),
#  ('army', 'NN'),
#  ('of', 'IN'),
#  ('lions', 'NNS'),
#  ('led', 'VBN'),
#  ('by', 'IN'),
#  ('a', 'DT'),
#  ('sheep', 'NN'),
#  (';', ':'),
#  ('I', 'PRP'),
#  ('am', 'VBP'),
#  ('afraid', 'JJ'),
#  ('of', 'IN'),
#  ('an', 'DT'),
#  ('army', 'NN'),
#  ('of', 'IN'),
#  ('sheep', 'NN'),
#  ('led', 'VBN'),
#  ('by', 'IN'),
#  ('a', 'DT'),
#  ('lion', 'NN'),
#  ('.', '.')]

# %%
print("Name: Shoaib Jamadar","UIN :231A008")
import nltk
nltk.download('tagsets_json')
nltk.help.upenn_tagset("DT")
nltk.help.upenn_tagset("VBD")
nltk.help.upenn_tagset("PRP")
# Out:
# Name: Shoaib Jamadar UIN :231A008
# DT: determiner
#     all an another any both del each either every half la many much nary
#     neither no some such that the them these this those
# VBD: verb, past tense
#     dipped pleaded swiped regummed soaked tidied convened halted registered
#     cushioned exacted snubbed strode aimed adopted belied figgered
#     speculated wore appreciated contemplated ...
# PRP: pronoun, personal
#     hers herself him himself hisself it itself me myself one oneself ours
#     ourselves ownself self she thee theirs them themselves they thou thy us
# [nltk_data] Downloading package tagsets_json to /root/nltk_data...
# [nltk_data]   Package tagsets_json is already up-to-date!

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
print("Name: Shoaib Jamadar","UIN :231A008")
import nltk
from nltk.chunk import ne_chunk
nltk.download('maxent_ne_chunker_tab')
named_entities = ne_chunk(tagged)
print(named_entities)
# Out:
# Name: Shoaib Jamadar UIN :231A008
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# (S
#   I/PRP
#   am/VBP
#   not/RB
#   afraid/JJ
#   of/IN
#   an/DT
#   army/NN
#   of/IN
#   lions/NNS
#   led/VBN
#   by/IN
#   a/DT
#   sheep/NN
#   ;/:
#   I/PRP
#   am/VBP
#   afraid/JJ
#   of/IN
#   an/DT
#   army/NN
#   of/IN
#   sheep/NN
#   led/VBN
#   by/IN
#   a/DT
#   lion/NN
#   ./.)

# %%
#Display named entities
for subtree in named_entities:
  entity = ""
  label = ""
  if isinstance(subtree, nltk.Tree):
    # This block handles actual named entities like (PERSON Barack Obama)
    entity_words = [word for word, tag in subtree.leaves()]
    entity = " ".join(entity_words) # Join with space for readability
    label = subtree.label()
  else:
    # This block handles individual word/tag tuples
    entity = subtree[0]
    label = subtree[1]

  print(f"Entity : {entity} , Label : {label}")
# Out:
# Entity : I , Label : PRP
# Entity : am , Label : VBP
# Entity : not , Label : RB
# Entity : afraid , Label : JJ
# Entity : of , Label : IN
# Entity : an , Label : DT
# Entity : army , Label : NN
# Entity : of , Label : IN
# Entity : lions , Label : NNS
# Entity : led , Label : VBN
# Entity : by , Label : IN
# Entity : a , Label : DT
# Entity : sheep , Label : NN
# Entity : ; , Label : :
# Entity : I , Label : PRP
# Entity : am , Label : VBP
# Entity : afraid , Label : JJ
# Entity : of , Label : IN
# Entity : an , Label : DT
# Entity : army , Label : NN
# Entity : of , Label : IN
# Entity : sheep , Label : NN
# Entity : led , Label : VBN
# Entity : by , Label : IN
# Entity : a , Label : DT
# Entity : lion , Label : NN
# Entity : . , Label : .

# %% [markdown]
# **Part Two Chunking**

# %%
from nltk.chunk import RegexpParser

# %%
print("Name: Shoaib Jamadar","UIN :231A008")
#e.g., NP Noun Phrase)
grammar = "NP: {<DT>?<JJ>*<NN.*>}"
# Out:
# Name: Shoaib Jamadar UIN :231A008

# %%
print("Name: Shoaib Jamadar","UIN :231A008")
chunk_parser = RegexpParser(grammar)
chunked = chunk_parser.parse(tagged)
print (chunked)
# Out:
# Name: Shoaib Jamadar UIN :231A008
# (S
#   I/PRP
#   am/VBP
#   not/RB
#   afraid/JJ
#   of/IN
#   (NP an/DT army/NN)
#   of/IN
#   (NP lions/NNS)
#   led/VBN
#   by/IN
#   (NP a/DT sheep/NN)
#   ;/:
#   I/PRP
#   am/VBP
#   afraid/JJ
#   of/IN
#   (NP an/DT army/NN)
#   of/IN
#   (NP sheep/NN)
#   led/VBN
#   by/IN
#   (NP a/DT lion/NN)
#   ./.)

# %%
print("Name: Shoaib Jamadar","UIN :231A008")
from nltk.tree import tree
chunked.pretty_print()
# Out:
# Name: Shoaib Jamadar UIN :231A008
#                                                                                            S
#    ________________________________________________________________________________________|____________________________________________________________________________________________________
#   |     |      |        |       |     |      |      |    |    |     |        |       |     |      |      |    |         NP             NP          NP                 NP            NP          NP
#   |     |      |        |       |     |      |      |    |    |     |        |       |     |      |      |    |     ____|_____         |       ____|_____         ____|_____        |       ____|_____
# I/PRP am/VBP not/RB afraid/JJ of/IN of/IN led/VBN by/IN ;/: I/PRP am/VBP afraid/JJ of/IN of/IN led/VBN by/IN ./. an/DT     army/NN lions/NNS a/DT     sheep/NN an/DT     army/NN sheep/NN a/DT     lion/NN

# %%
grammar1 = "VP: {<MD>?<RB.*>*<VB.*>+}"
chunk_parser = RegexpParser (grammar1)
chunked1 = chunk_parser.parse(tagged)

# %%
print("Name: Shoaib Jamadar","UIN :231A008")
print(chunked1)
chunked1.pretty_print()
# Out:
# Name: Shoaib Jamadar UIN :231A008
# (S
#   I/PRP
#   (VP am/VBP)
#   not/RB
#   afraid/JJ
#   of/IN
#   an/DT
#   army/NN
#   of/IN
#   lions/NNS
#   (VP led/VBN)
#   by/IN
#   a/DT
#   sheep/NN
#   ;/:
#   I/PRP
#   (VP am/VBP)
#   afraid/JJ
#   of/IN
#   an/DT
#   army/NN
#   of/IN
#   sheep/NN
#   (VP led/VBN)
#   by/IN
#   a/DT
#   lion/NN
#   ./.)
#                                                                                              S
#    __________________________________________________________________________________________|________________________________________________________________________________________
#   |     |        |       |     |      |      |       |       |    |      |      |    |       |       |     |      |      |      |       |    |      |     |    VP      VP     VP      VP
# ...
