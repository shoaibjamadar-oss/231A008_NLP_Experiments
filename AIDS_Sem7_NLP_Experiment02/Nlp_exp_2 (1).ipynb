# %%
print("Shoaib Jamadar","UIN:231A008")
import nltk
from nltk.corpus import twitter_samples
import matplotlib.pyplot as plt
import random
# Out:
# Shoaib Jamadar UIN:231A008

# %%
#download sample twitter dataset
nltk.download('twitter_samples')
# Out:
# [nltk_data] Downloading package twitter_samples to /root/nltk_data...
# [nltk_data]   Unzipping corpora/twitter_samples.zip.
# True

# %%
twitter_samples.fileids()
# Out:
# ['negative_tweets.json', 'positive_tweets.json', 'tweets.20150430-223406.json']

# %%
#select the set of positive and negative tweets
positive_tweets = twitter_samples.strings('positive_tweets.json')
negative_tweets = twitter_samples.strings('negative_tweets.json')

# %%
print("Shoaib Jamadar","UIN:231A008")
print('Number of positive tweets:', len(positive_tweets))
print('Number of negative tweets:', len(negative_tweets))

print('\nThe type of all positive tweets:', type(positive_tweets))
print('\nThe type of a tweet entry is:', type(negative_tweets[0]))
# Out:
# Shoaib Jamadar UIN:231A008
# Number of positive tweets: 5000
# Number of negative tweets: 5000
#
# The type of all positive tweets: <class 'list'>
#
# The type of a tweet entry is: <class 'str'>

# %%
positive_tweets[4]
# Out:
# 'yeaaaah yippppy!!!  my accnt verified rqst has succeed got a blue tick mark on my fb profile :) in 15 days'

# %%
negative_tweets[4]
# Out:
# 'Dang starting next week I have "work" :('

# %%
print("Shoaib Jamadar","UIN:231A008")
import pandas as pd
positive_tweets = pd.DataFrame(positive_tweets,columns=["Tweets"])
negative_tweets = pd.DataFrame(negative_tweets,columns=["Tweets"])
# Out:
# Shoaib Jamadar UIN:231A008

# %%
positive_tweets['Sentiment'] = 'Positive'
positive_tweets.head()
# Out:
#                                               Tweets Sentiment
# 0  #FollowFriday @France_Inte @PKuchly57 @Milipol...  Positive
# 1  @Lamb2ja Hey James! How odd :/ Please call our...  Positive
# 2  @DespiteOfficial we had a listen last night :)...  Positive
# 3                               @97sides CONGRATS :)  Positive
# 4  yeaaaah yippppy!!!  my accnt verified rqst has...  Positive

# %%
negative_tweets['Sentiment'] = 'Negative'
negative_tweets.head()
# Out:
#                                               Tweets Sentiment
# 0                                hopeless for tmr :(  Negative
# 1  Everything in the kids section of IKEA is so c...  Negative
# 2  @Hegelbon That heart sliding into the waste ba...  Negative
# 3  “@ketchBurning: I hate Japanese call him "bani...  Negative
# 4           Dang starting next week I have "work" :(  Negative

# %%
print("Shoaib Jamadar","UIN:231A008")
all_tweets=pd.concat([positive_tweets,negative_tweets],ignore_index=True)
all_tweets
# Out:
# Shoaib Jamadar UIN:231A008
#                                                  Tweets Sentiment
# 0     #FollowFriday @France_Inte @PKuchly57 @Milipol...  Positive
# 1     @Lamb2ja Hey James! How odd :/ Please call our...  Positive
# 2     @DespiteOfficial we had a listen last night :)...  Positive
# 3                                  @97sides CONGRATS :)  Positive
# 4     yeaaaah yippppy!!!  my accnt verified rqst has...  Positive
# ...                                                 ...       ...
# 9995               I wanna change my avi but uSanele :(  Negative
# 9996                         MY PUPPY BROKE HER FOOT :(  Negative
# 9997           where's all the jaebum baby pictures :((  Negative
# 9998  But but Mr Ahmad Maslan cooks too :( https://t...  Negative
# 9999  @eawoman As a Hull supporter I am expecting a ...  Negative
#
# [10000 rows x 2 columns]

# %%
print("Shoaib Jamadar","UIN:231A008")
all_tweets=all_tweets.sample(frac=1,random_state=42).reset_index(drop=True)
all_tweets
# Out:
# Shoaib Jamadar UIN:231A008
#                                                  Tweets Sentiment
# 0     I love you, how but you? @Taecyeon2pm8 did you...  Negative
# 1     @mayusushita @dildeewana_ @sonalp2591 @deepti_...  Positive
# 2     Your love, O Lord, is better than life. :) &lt...  Positive
# 3     @yasminyasir96 yeah but it will be better if w...  Positive
# 4     Ok good night I wish troye wasn't ugly and I m...  Positive
# ...                                                 ...       ...
# 9995                My nose and forehead are peeling :(  Negative
# 9996                      @LittleMix come to Belgium :(  Negative
# 9997                     WHY MUST THE VIDEO STOP THO :(  Negative
# 9998  @jeremygutsche we like this amazing donut reci...  Positive
# 9999  @alma @iamrrr ON LOOP... Bad news for the peop...  Negative
#
# [10000 rows x 2 columns]

# %%
print("Shoaib Jamadar","UIN:231A008")
all_tweets.head(10)
# Out:
# Shoaib Jamadar UIN:231A008
#                                               Tweets Sentiment
# 0  I love you, how but you? @Taecyeon2pm8 did you...  Negative
# 1  @mayusushita @dildeewana_ @sonalp2591 @deepti_...  Positive
# 2  Your love, O Lord, is better than life. :) &lt...  Positive
# 3  @yasminyasir96 yeah but it will be better if w...  Positive
# 4  Ok good night I wish troye wasn't ugly and I m...  Positive
# 5  @scottybev I'm not surprised, that sounds hell...  Negative
# 6  Dry, hot, scorching summer #FF :) @infocffm @M...  Positive
# 7                     @hanbined sad pray for me :(((  Negative
# 8                                   Popol day too :(  Negative
# 9  My Song of the Week is Ducktails - Surreal Exp...  Positive

# %%
print("Shoaib Jamadar","UIN:231A008")
y_positive=(all_tweets["Sentiment"]=="Positive").sum()
y_negative=(all_tweets["Sentiment"]=="Negative").sum()
print(y_positive,y_negative)
# Out:
# Shoaib Jamadar UIN:231A008
# 5000 5000

# %%
print("Shoaib Jamadar","UIN:231A008")
#Declare a figure with a custom size
fig = plt.figure(figsize=(5, 4))

#labels for the two classes
labels = 'Positive', 'Negative'

#sizes for each section
sizes = [y_positive, y_negative]

#Declare pie chart,where the slices will be ordered and plotted counter-clockwise:
plt.bar(labels,sizes)

plt.show()
# Out:
# Shoaib Jamadar UIN:231A008

# %%
#Observation: Plotted a bar chart comparing the count of positive vs negative tweets
#Next: Select a sample tweet from the dataset to demonstrate the text preprocessing step by step.

# %%
print("Shoaib Jamadar","UIN:231A008")
tweet1=all_tweets.iloc[1000]
tweet1["Tweets"]
# Out:
# Shoaib Jamadar UIN:231A008
# '@djcunningham Thanks for the favorite! :) Make sure to keep in touch for more news of our light bulbs made from corn waste.'

# %%
#Observation: Selected a single sample tweet (row 1000) from the dataset to use as a running example for cleaning and tokenization.
#Next: Import the libraries needed for text cleaning re, string, stopwords, stemmer, and tokenizer.

# %%
import re
import string
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import TweetTokenizer

# %%
#Observation: Imported regex, string, NLTK stopwords, the Porter stemmer, and the tweet-specific tokenizer needed for the preprocessing.
#Next: Clean the sample tweet by removing retweet tags, links, hashtags, and mentions.

# %%
print("Shoaib Jamadar","UIN:231A008")
#remove old style retweet text "RT"
tweet2=re.sub(r'^RT[\s]+','',tweet1["Tweets"])

#remove hyperlinks
tweet2=re.sub(r'https?:\/\/.*[\r\n]*','',tweet2)

#remove hashtags
#only removing the hash # sign from the word
tweet2=re.sub(r'#','',tweet2)
tweet2=re.sub(r'@\w+','',tweet2)
tweet2=re.sub(r'[:)|(:)]','',tweet2)
print(tweet1["Tweets"])
print("\n Cleaned tweet\n", tweet2)
# Out:
# Shoaib Jamadar UIN:231A008
# @djcunningham Thanks for the favorite! :) Make sure to keep in touch for more news of our light bulbs made from corn waste.
#
#  Cleaned tweet
#   Thanks for the favorite!  Make sure to keep in touch for more news of our light bulbs made from corn waste.

# %%
#Observation: Cleaned the sample tweet by removing "RT" retweet markers, hyperlinks, hashtag symbols, mentions (@user), and emoticon-style colons/parentheses, then printed the original vs cleaned version side-by-side.
#Next: Tokenize the cleaned tweet into individual words.

# %%
print("Shoaib Jamadar","UIN:231A008")
tokenizer = TweetTokenizer(preserve_case=False, strip_handles=True,
                               reduce_len=True)
tweet_tokens = tokenizer.tokenize(tweet2)

print('String with all punctuation marks:\n')
print(string.punctuation)
print('\nList of English stopwords:\n')
nltk.download('stopwords') # Added this line to download the stopwords corpus
print(stopwords.words('english'))

print('\nTokenized string:\n')
print(tweet_tokens)
# Out:
# Shoaib Jamadar UIN:231A008
# String with all punctuation marks:
#
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
#
# List of English stopwords:
#
# ...

# %%
print("Shoaib Jamadar","UIN:231A008")
nltk.download('stopwords')
stopwords_english = stopwords.words('english')
print('stop words\n')
print(stopwords_english)

print('\nPunctuation\n')
print(string.punctuation)
# Out:
# Shoaib Jamadar UIN:231A008
# stop words
#
# ...

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
print("Shoaib Jamadar","UIN:231A008")
stopwords_english = stopwords.words('english')
print('stop words\n')
print(stopwords_english)

print('\nPunctuation\n')
print(string.punctuation)
# Out:
# Shoaib Jamadar UIN:231A008
# stop words
#
# ...

# %%
#Observation: Removed all stopwords and punctuation marks from the tokenized tweet, leaving only the meaningful content words, and printed before/after lists for comparison.
#Next: Wrap all the above preprocessing steps into a single reusable function.

# %%
print("Shoaib Jamadar","UIN:231A008")
print(tweet_tokens)
print()
# print('\033[94m')
tweet_clean=[]
for word in tweet_tokens:
    if (word not in stopwords_english and word not in string.punctuation):
        tweet_clean.append(word)
print('removed stop word and punctuation')
print(tweet_clean)
# Out:
# Shoaib Jamadar UIN:231A008
# ['thanks', 'for', 'the', 'favorite', '!', 'make', 'sure', 'to', 'keep', 'in', 'touch', 'for', 'more', 'news', 'of', 'our', 'light', 'bulbs', 'made', 'from', 'corn', 'waste', '.']
#
# removed stop word and punctuation
# ['thanks', 'favorite', 'make', 'sure', 'keep', 'touch', 'news', 'light', 'bulbs', 'made', 'corn', 'waste']

# %%
print("Shoaib Jamadar","UIN:231A008")
def clean_tweet(tweet):
    tokenizer = TweetTokenizer(preserve_case=False, strip_handles=True,
                               reduce_len=True)
    # remove old style retweet text "RT"
    tweet = re.sub(r'^RT[\s]+','',tweet)
    # remove hyperlinks
    tweet = re.sub(r'https?://.*[\r\n]*','',tweet)
    # remove hashtags and mentions
    tweet = re.sub(r'#','',tweet)
    tweet = re.sub(r'@\w+','',tweet)
    # remove colons and parentheses (if intended as part of cleaning, otherwise remove this line)
    tweet = re.sub(r'[:)|(:)]','',tweet)
    tweet_tokens = tokenizer.tokenize(tweet)
    tweets_clean=[]
    for word in tweet_tokens:
        if (word not in stopwords_english and word not in string.punctuation):
            tweets_clean.append(word)
    return tweets_clean
# Out:
# Shoaib Jamadar UIN:231A008

# %%
#Observation: Defined a reusable function process_tweet() that combines all previous steps removing RT tags, links, hashtags, mentions, tokenizing, and filtering out stopwords/punctuation — into one pipeline for any tweet.
#Next: Apply this function to the one entry of dataset

# %%
print("Shoaib Jamadar","UIN:231A008")
tweet1=all_tweets.iloc[200]
tweet=tweet1["Tweets"]
print(clean_tweet(tweet))
# Out:
# Shoaib Jamadar UIN:231A008
# ['mumma', 'im', '7']

# %%
print("Shoaib Jamadar","UIN:231A008")
cleaned_tweets = all_tweets['Tweets'].apply(clean_tweet)
all_tweets['Tweets_processed'] = cleaned_tweets
pd.set_option('display.max_colwidth', None)
all_tweets
# Out:
# Shoaib Jamadar UIN:231A008
#                                                                  Tweets  \
# 0                                                   love feel emm think
# 1                                                           thanks guys
# 2                                              love lord better life <3
# 3                             yeah better use official account like ❤ ️
# 4     ok good night wish troye ugly met today ok today fun excited tmrw
# ...                                                                 ...
# 9995                                              nose forehead peeling
# 9996                                                       come belgium
# 9997                                                must video stop tho
# 9998                    like amazing donut recipe share foiegras lovers
# 9999                   loop ... bad news people provide feedback though
#
#      Sentiment  \
# 0     Negative
# 1     Positive
# 2     Positive
# ...

# %%
#Observation: Applied the process_tweet() function to every tweet in the dataset and stored the cleaned/tokenized result in a new column Tweets_processed, displaying the final DataFrame with both raw and processed tweet text

# %%
print("Shoaib Jamadar","UIN:231A008")
cleaned_tweets = all_tweets['Tweets'].apply(clean_tweet)
all_tweets['Tweets_processed'] = cleaned_tweets
all_tweets[['Sentiment', 'Tweets_processed']]
# Out:
# Shoaib Jamadar UIN:231A008
#      Sentiment  \
# 0     Negative
# 1     Positive
# 2     Positive
# 3     Positive
# 4     Positive
# ...        ...
# 9995  Negative
# 9996  Negative
# 9997  Negative
# 9998  Positive
# 9999  Negative
#
#                                                                      Tweets_processed
# 0                                                            [love, feel, emm, think]
# 1                                                                      [thanks, guys]
# 2                                                      [love, lord, better, life, <3]
# 3                                  [yeah, better, use, official, account, like, ❤, ️]
# 4     [ok, good, night, wish, troye, ugly, met, today, ok, today, fun, excited, tmrw]
# ...                                                                               ...
# 9995                                                        [nose, forehead, peeling]
# ...

# %%
all_tweets["Tweets"] = all_tweets["Tweets_processed"].apply(lambda x: " ".join(x))

# %%
print("Shoaib Jamadar","UIN:231A008")
processed_tweets_a112 = all_tweets[['Tweets', 'Sentiment']]
processed_tweets_a112.head()
# Out:
# Shoaib Jamadar UIN:231A008
#                                                               Tweets Sentiment
# 0                                                love feel emm think  Negative
# 1                                                        thanks guys  Positive
# 2                                           love lord better life <3  Positive
# 3                          yeah better use official account like ❤ ️  Positive
# 4  ok good night wish troye ugly met today ok today fun excited tmrw  Positive
